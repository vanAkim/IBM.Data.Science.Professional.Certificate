# %%
lat_tls = 43.6016
lng_tls = 1.4407

# %%
import json, requests
url = 'https://api.foursquare.com/v2/venues/explore'

params = dict(
client_id='3HKNONV5WQ0YZJUOEYSE0221FMCZQDZHKNQ0W4ZG1P5XW2KW',
client_secret='0TIKF1OFORWQTIPFVVLMGHHQST3LPPTBLMKXATPVIUPFJXUU',
v='20180323',
ll=str(lat_tls) + ',' + str(lng_tls),
query='loisirs',
limit=200,
locale='fr',
radius=1800
)

resp = requests.get(url=url, params=params)
data = json.loads(resp.text)
items = data['response']['groups'][0]['items']

# %%
from pandas import json_normalize

dataframe = json_normalize(items) # flatten JSON

filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head()
# Out:
#                                     name        categories            address  \
# 0                    Théâtre du Capitole             Opéra  Place du Capitole
# 1  Hôtel de Ville de Toulouse (Capitole)    Hôtel de ville  Place du Capitole
# 2                    Musée des Augustins       Musée d'art     21 Rue de Metz
# 3         Parc de la Prairie des Filtres              Parc       Cours Dillon
# 4                               Rio Loco  Salle de concert                NaN
#
#          lat       lng                                     labeledLatLngs  \
# 0  43.604130  1.444332  [{'label': 'display', 'lat': 43.60412979544746...
# 1  43.604523  1.444179  [{'label': 'display', 'lat': 43.60452250885116...
# 2  43.601170  1.446397  [{'label': 'display', 'lat': 43.6011697382502,...
# 3  43.595638  1.436977  [{'label': 'display', 'lat': 43.59563769241053...
# 4  43.596345  1.436907  [{'label': 'display', 'lat': 43.59634529848775...
#
#    distance postalCode  cc      city          state country  \
# 0       406      31000  FR  Toulouse  Midi-Pyrénées  France
# 1       429      31000  FR  Toulouse  Midi-Pyrénées  France
# 2       461      31000  FR  Toulouse  Midi-Pyrénées  France
# 3       728      31300  FR  Toulouse  Midi-Pyrénées  France
# 4       660        NaN  FR  Toulouse  Midi-Pyrénées  France
#
#                                     formattedAddress    crossStreet  \
# 0        [Place du Capitole, 31000 Toulouse, France]            NaN
# 1  [Place du Capitole (Rue Lafayette), 31000 Toul...  Rue Lafayette
# 2           [21 Rue de Metz, 31000 Toulouse, France]            NaN
# 3             [Cours Dillon, 31300 Toulouse, France]            NaN
# 4                                 [Toulouse, France]            NaN
#
#                          id
# 0  4c84b599d92ea093f9785f72
# 1  4c03b2459a7920a19230d079
# 2  4b96adcbf964a52077dd34e3
# 3  4bc1c05df8219c7456bbb310
# 4  4df7a497fa76511d0048d1bb

# %%
categorie_labels = {
    # Watch a show
    "spectacle": ["Opéra", "Théâtre", "Salle de spectacle", "Complexe des arts de la scène"],
    "cinema": ["Multiplexe", "Cinéma indépendant", "Cinéma"],
    "music": ["Salle de concert", "Auditorium"],

    # Visit a place
    "monument": ["Hôtel de ville", "Base militaire", "Église", "Site historique"],

    # Play
    "sport": ["Stade de basketball", "Stade de football", "Café des sports", "Salle de danse", "Stade"],
    "game": ["Salle d'arcade", "Parc d'attractions"],

    # Interact with culture
    "exposition": ["Musée d'art", "Musée des sciences", "Galerie d'art", "Musée d'histoire", "École"],

    # Enjoy green
    "parc": ["Parc", "Jardin"]
}

# %%
for i, cat_val in enumerate(categorie_labels.values()):
    filt = list(map(lambda cat_venu: cat_venu in cat_val,
                    dataframe_filtered['categories']))
    dataframe_filtered.loc[filt,'categories'] = list(categorie_labels.keys())[i]

print(dataframe_filtered.shape)
dataframe_filtered["categories"].unique()
# Out:
# (33, 15)
# array(['spectacle', 'monument', 'exposition', 'parc', 'music', 'cinema',
#        'sport', 'Complexe des arts de la\xa0scène'], dtype=object)

# %%
import folium

toulouse_map = folium.Map(location=[lat_tls, lng_tls], zoom_start=15, tiles="cartoDB positron")

for lat, lng, name, cat in zip(dataframe_filtered['lat'], dataframe_filtered['lng'], dataframe_filtered['name'], dataframe_filtered['categories']):
    label = '{}'.format(name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=8,
        popup=label,
        color='#205E40',
        fill=True,
        opacity=0,
        fill_color='#3AAB74',
        fill_opacity=0.7,
        parse_html=False).add_to(toulouse_map)

toulouse_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import geopandas
import pandas as pd

url = "https://data.toulouse-metropole.fr/explore/dataset/comptages-pietons/download/?format=geojson&timezone=Europe/Berlin&lang=fr"

tls_pedestrian = geopandas.read_file(url)

# %%
tls_pedestrian.head()
# Out:
#   moment_dans_la_journee comptage                         adresse  \
# 0                   midi      893  devant la brasserie rue Bayard
# 1                   midi      700  devant la brasserie rue Bayard
# 2                   soir      854  devant la brasserie rue Bayard
# 3                   soir     1178  devant la brasserie rue Bayard
# 4                   soir      925  devant la brasserie rue Bayard
#
#           transposee    jours   annee                  geometry
# 0  semaine_midi_2006  semaine  2006.0  POINT (1.44588 43.60783)
# 1   samedi_midi_2015   samedi  2015.0  POINT (1.44588 43.60783)
# 2  semaine_soir_2013  semaine  2013.0  POINT (1.44588 43.60783)
# 3   samedi_soir_2013   samedi  2013.0  POINT (1.44588 43.60783)
# 4   samedi_soir_2012   samedi  2012.0  POINT (1.44588 43.60783)

# %%
# Remove useless features
tls_pedestrian.drop(["transposee", "jours"], axis=1, inplace=True)

# Slice most recent data
filt = tls_pedestrian['annee'] >= 2016
tls_pedestrian = tls_pedestrian.loc[filt]

# Transform geometry feature type into a simple lat-lng list
tls_pedestrian['latitude'] = tls_pedestrian['geometry'].bounds['miny']
tls_pedestrian['longitude'] = tls_pedestrian['geometry'].bounds['minx']

# Change features types and names
tls_pedestrian['comptage'] = tls_pedestrian['comptage'].astype(int)
tls_pedestrian['annee'] = tls_pedestrian['annee'].astype(str)
tls_pedestrian['latitude'] = tls_pedestrian['latitude'].astype(str)
tls_pedestrian['longitude'] = tls_pedestrian['longitude'].astype(str)

tls_pedestrian.columns = ["day_time", "count", "address", "year", "geometry", "latitude", "longitude"]

# Format day_time feature labels
day_lab = ["journee", "midi", "matin"]
tls_pedestrian["day_time"] = list(map(lambda time: 'day' if time in day_lab else 'night',
                                      tls_pedestrian["day_time"]))

# Clean the index
tls_pedestrian.reset_index(drop=True, inplace=True)

# Overview
tls_pedestrian.head()
# Out:
#   day_time  count                         address    year  \
# 0      day   1058  devant la brasserie rue Bayard  2016.0
# 1      day    436  devant la brasserie rue Bayard  2018.0
# 2      day    232  devant la brasserie rue Bayard  2016.0
# 3      day   1153          77 rue Alsace Lorraine  2019.0
# 4      day      0          77 rue Alsace Lorraine  2018.0
#
#                    geometry            latitude          longitude
# 0  POINT (1.44588 43.60783)   43.60782556389234  1.445876790590295
# 1  POINT (1.44588 43.60783)   43.60782556389234  1.445876790590295
# 2  POINT (1.44588 43.60783)   43.60782556389234  1.445876790590295
# 3  POINT (1.44569 43.60792)  43.607917051233294  1.445685441081164
# 4  POINT (1.44569 43.60792)  43.607917051233294  1.445685441081164

# %%
tls_ped_grpby = tls_pedestrian.groupby(['address', 'year'], as_index=False).median()

# Remove null values
filt = tls_ped_grpby['count'] != 0
tls_ped_grpby = tls_ped_grpby[filt]

# Average values between years
tls_ped_grpby = tls_ped_grpby.groupby(['address'], as_index=False).median().round()

tls_ped_grpby = tls_ped_grpby.join(
    tls_pedestrian[['address','latitude','longitude']].drop_duplicates().set_index('address'),
    on="address")

print(tls_ped_grpby.shape)
tls_ped_grpby.head(7)
# Out:
# (80, 4)
#                             address   count           latitude  \
# 0                      1 Rue Bayard   812.0  43.60824205958672
# 1              1 place Jeanne d'Arc  2430.0  43.60857631673823
# 2                1 rue d'Austerlitz   952.0  43.60544214882909
# 3                   10 rue des Lois   676.0  43.60515870014418
# 4              10 rue des Tourneurs   904.0  43.59980685406695
# 5  11 Allées du Président Roosevelt  1155.0  43.60559474389562
# 6             11 place du Parlement   763.0  43.59429224932219
#
#            longitude
# 0  1.446576244291821
# 1   1.44587074534944
# 2  1.447397826384669
# 3   1.44227143410786
# 4   1.44526647441732
# 5  1.448230373315519
# 6  1.443841181690078

# %%
import branca

# Hex color function to transform values from specified cmap, here Oranges
colorscale = branca.colormap.linear.Oranges_09.scale(tls_ped_grpby['count'].min(), tls_ped_grpby['count'].max())

# Initial layout map
toulouse_map = folium.Map(location=[lat_tls, lng_tls], zoom_start=15, tiles="cartoDB positron")

# Adding counted pedestrian spots with circles
for lat, lng, colr, address, count in zip(tls_ped_grpby['latitude'], tls_ped_grpby['longitude'], tls_ped_grpby['color'], tls_ped_grpby['address'], tls_ped_grpby['count']):
    label = '{} | Count : {}'.format(address, int(count))
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [float(lat), float(lng)],
        radius=(count/200)+3,
        popup=label,
        color='#535760',
        opacity=0.7,
        fill=True,
        fill_color=colorscale(count),
        fill_opacity=0.9,
        parse_html=False).add_to(toulouse_map)

# Adding cultural venues
for lat, lng, name, cat in zip(dataframe_filtered['lat'], dataframe_filtered['lng'], dataframe_filtered['name'], dataframe_filtered['categories']):
    label = '{}'.format(name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=8,
        popup=label,
        color='#205E40',
        fill=True,
        opacity=0,
        fill_color='#3AAB74',
        fill_opacity=0.7,
        parse_html=False).add_to(toulouse_map)

# Show map
toulouse_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
dataframe_filtered['name'].pivot()
# Out:
#                                           name                     categories  \
# 0                          Théâtre du Capitole                      spectacle
# 1        Hôtel de Ville de Toulouse (Capitole)                       monument
# 2                          Musée des Augustins                     exposition
# 3               Parc de la Prairie des Filtres                           parc
# 4                                     Rio Loco                          music
# 5                               Gaumont Wilson                         cinema
# 6                            Fondation Bemberg                     exposition
# 7           Les Abattoirs - FRAC Midi-Pyrénées                     exposition
# 8                             Halle aux Grains                          music
# 9   Théâtre National de Toulouse Midi-Pyrénées                      spectacle
# 10                               Château d'eau                     exposition
# 11                          Muséum de Toulouse                     exposition
# 12                        Jardin du Grand Rond                           parc
# 13                               Cinéma Utopia                         cinema
# 14                              Théâtre Les 3T                      spectacle
# 15                                 Palais Niel                       monument
# 16                      La Comédie de Toulouse                      spectacle
# 17                Église Notre Dame la Dalbade                       monument
# 18                         Musée Saint-Raymond                     exposition
# 19                           Palais des sports                          sport
# 20                 La Cinémathèque de Toulouse                         cinema
# 21                                  Cinéma ABC                         cinema
# 22                                Le Seventies                          sport
# 23        Auditorium Saint Pierre Des Cuisines                          music
# 24                           Salle du Sénéchal                          music
# 25        Toulouse Plage - Chateaux Gonflables                           parc
# 26                                       Le 57                      spectacle
# 27                                      Le Rex                          music
# 28                             Theatre Garonne  Complexe des arts de la scène
# 29                       Virgin Radio Toulouse                          music
# 30                     FENIX Toulouse Handball                          sport
# 31                         Centre James Carlès                          sport
# 32                               Au 10ème Ciel                      spectacle
#
#                                address        lat       lng  \
# 0                    Place du Capitole  43.604130  1.444332
# 1                    Place du Capitole  43.604523  1.444179
# 2                       21 Rue de Metz  43.601170  1.446397
# 3                         Cours Dillon  43.595638  1.436977
# 4                                  NaN  43.596345  1.436907
# 5   3 place du Président Thomas Wilson  43.604251  1.448624
# 6                      Hôtel d'Assézat  43.600408  1.441880
# 7           76 Allées Charles de Fitte  43.600773  1.429066
# 8                          Place Dupuy  43.600015  1.454166
# 9                       1-3 rue Labeda  43.604209  1.449935
# 10                     1 Place Laganne  43.598832  1.436718
# 11               35 Allée Jules Guesde  43.593853  1.449469
# 12                   Square Boulingrin  43.595987  1.452373
# 13                     24 Rue Montardy  43.604095  1.446715
# 14                 40 rue Gabriel Péri  43.606037  1.455694
# 15        Rue Montoulieu Saint-Jacques  43.597029  1.451311
# 16                   Rue Saint-Germier  43.611599  1.441049
# 17                       place dalbade  43.597715  1.442185
# 18                  Place Saint-Sernin  43.607728  1.441115
# 19                                 NaN  43.612388  1.435369
# 20                         rue du Taur  43.606907  1.441664
# 21                13 rue Saint-Bernard  43.609187  1.443958
# 22              42, port Saint Etienne  43.600702  1.456551
# 23                  Place Saint-Pierre  43.603480  1.437056
# 24                      Rue de Rémusat  43.606315  1.444245
# 25                                 NaN  43.595260  1.436907
# 26                                 NaN  43.608944  1.430795
# 27             31 Avenue Honoré Serres  43.611770  1.438389
# 28           1 avenue du chateau d'eau  43.602630  1.425381
# 29           10 place Alfonse Jourdain  43.610598  1.431269
# 30                3 rue Pierre Laplace  43.612466  1.434746
# 31                                 NaN  43.606316  1.423230
# 32                                 NaN  43.593866  1.456339
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 43.60412979544746...       406      31000
# 1   [{'label': 'display', 'lat': 43.60452250885116...       429      31000
# 2   [{'label': 'display', 'lat': 43.6011697382502,...       461      31000
# 3   [{'label': 'display', 'lat': 43.59563769241053...       728      31300
# 4   [{'label': 'display', 'lat': 43.59634529848775...       660        NaN
# 5   [{'label': 'display', 'lat': 43.60425144568281...       703      31000
# 6   [{'label': 'display', 'lat': 43.60040833515997...       163      31000
# 7   [{'label': 'display', 'lat': 43.60077327117476...       942      31300
# 8   [{'label': 'display', 'lat': 43.60001468134042...      1099      31000
# 9   [{'label': 'display', 'lat': 43.60420866143894...       799      31000
# 10  [{'label': 'display', 'lat': 43.59883235984153...       444      31300
# 11  [{'label': 'display', 'lat': 43.59385285900747...      1115      31000
# 12  [{'label': 'display', 'lat': 43.59598655276457...      1129      31000
# 13  [{'label': 'display', 'lat': 43.6040946638791,...       558      31000
# 14  [{'label': 'display', 'lat': 43.60603730107047...      1305      31000
# 15  [{'label': 'display', 'lat': 43.59702852145882...       995      31000
# 16  [{'label': 'display', 'lat': 43.61159853137442...      1113      31000
# 17  [{'label': 'display', 'lat': 43.59771544891311...       448        NaN
# 18  [{'label': 'display', 'lat': 43.60772789743526...       682      31000
# 19  [{'label': 'display', 'lat': 43.61238847738681...      1275        NaN
# 20  [{'label': 'display', 'lat': 43.60690683032786...       595        NaN
# 21  [{'label': 'display', 'lat': 43.60918651515907...       884      31000
# 22  [{'label': 'display', 'lat': 43.6007015142495,...      1281      31000
# 23  [{'label': 'display', 'lat': 43.60348011091108...       360      31000
# 24  [{'label': 'display', 'lat': 43.60631518809386...       597        NaN
# 25  [{'label': 'display', 'lat': 43.59526016248241...       769        NaN
# 26  [{'label': 'display', 'lat': 43.60894396139502...      1142        NaN
# 27  [{'label': 'display', 'lat': 43.61176956247764...      1147      31000
# 28  [{'label': 'display', 'lat': 43.60263019629185...      1240      31300
# 29  [{'label': 'display', 'lat': 43.61059799883178...      1257      31000
# 30  [{'label': 'display', 'lat': 43.61246558843788...      1301      31000
# 31  [{'label': 'display', 'lat': 43.60631620154687...      1502        NaN
# 32  [{'label': 'display', 'lat': 43.59386615834853...      1526        NaN
#
#     cc      city          state country  \
# 0   FR  Toulouse  Midi-Pyrénées  France
# 1   FR  Toulouse  Midi-Pyrénées  France
# 2   FR  Toulouse  Midi-Pyrénées  France
# 3   FR  Toulouse  Midi-Pyrénées  France
# 4   FR  Toulouse  Midi-Pyrénées  France
# 5   FR  Toulouse  Midi-Pyrénées  France
# 6   FR  Toulouse  Midi-Pyrénées  France
# 7   FR  Toulouse  Midi-Pyrénées  France
# 8   FR  Toulouse  Midi-Pyrénées  France
# 9   FR  Toulouse  Midi-Pyrénées  France
# 10  FR  Toulouse  Midi-Pyrénées  France
# 11  FR  Toulouse  Midi-Pyrénées  France
# 12  FR  Toulouse  Midi-Pyrénées  France
# 13  FR  Toulouse  Midi-Pyrénées  France
# 14  FR  Toulouse  Midi-Pyrénées  France
# 15  FR  Toulouse  Midi-Pyrénées  France
# 16  FR  Toulouse  Midi-Pyrénées  France
# 17  FR  Toulouse  Midi-Pyrénées  France
# 18  FR  Toulouse  Midi-Pyrénées  France
# 19  FR       NaN            NaN  France
# 20  FR  Toulouse  Midi-Pyrénées  France
# 21  FR  Toulouse  Midi-Pyrénées  France
# 22  FR  Toulouse  Midi-Pyrénées  France
# 23  FR  Toulouse  Midi-Pyrénées  France
# 24  FR  Toulouse  Midi-Pyrénées  France
# 25  FR       NaN            NaN  France
# 26  FR       NaN            NaN  France
# 27  FR  Toulouse  Midi-Pyrénées  France
# 28  FR  Toulouse  Midi-Pyrénées  France
# 29  FR  Toulouse  Midi-Pyrénées  France
# 30  FR  Toulouse  Midi-Pyrénées  France
# 31  FR       NaN            NaN  France
# 32  FR       NaN            NaN  France
#
#                                      formattedAddress      crossStreet  \
# 0         [Place du Capitole, 31000 Toulouse, France]              NaN
# 1   [Place du Capitole (Rue Lafayette), 31000 Toul...    Rue Lafayette
# 2            [21 Rue de Metz, 31000 Toulouse, France]              NaN
# 3              [Cours Dillon, 31300 Toulouse, France]              NaN
# 4                                  [Toulouse, France]              NaN
# 5   [3 place du Président Thomas Wilson, 31000 Tou...              NaN
# 6           [Hôtel d'Assézat, 31000 Toulouse, France]              NaN
# 7   [76 Allées Charles de Fitte, 31300 Toulouse, F...              NaN
# 8               [Place Dupuy, 31000 Toulouse, France]              NaN
# 9            [1-3 rue Labeda, 31000 Toulouse, France]              NaN
# 10          [1 Place Laganne, 31300 Toulouse, France]              NaN
# 11    [35 Allée Jules Guesde, 31000 Toulouse, France]              NaN
# 12        [Square Boulingrin, 31000 Toulouse, France]              NaN
# 13          [24 Rue Montardy, 31000 Toulouse, France]              NaN
# 14      [40 rue Gabriel Péri, 31000 Toulouse, France]              NaN
# 15  [Rue Montoulieu Saint-Jacques, 31000 Toulouse,...              NaN
# 16        [Rue Saint-Germier, 31000 Toulouse, France]              NaN
# 17                  [place dalbade, Toulouse, France]              NaN
# 18       [Place Saint-Sernin, 31000 Toulouse, France]              NaN
# 19                                           [France]              NaN
# 20                    [rue du Taur, Toulouse, France]              NaN
# 21     [13 rue Saint-Bernard, 31000 Toulouse, France]              NaN
# 22   [42, port Saint Etienne, 31000 Toulouse, France]              NaN
# 23       [Place Saint-Pierre, 31000 Toulouse, France]              NaN
# 24  [Rue de Rémusat (Rue du Senechal), Toulouse, F...  Rue du Senechal
# 25                                           [France]              NaN
# 26                                           [France]              NaN
# 27  [31 Avenue Honoré Serres, 31000 Toulouse, France]              NaN
# 28  [1 avenue du chateau d'eau, 31300 Toulouse, Fr...              NaN
# 29  [10 place Alfonse Jourdain, 31000 Toulouse, Fr...              NaN
# 30     [3 rue Pierre Laplace, 31000 Toulouse, France]              NaN
# 31                                           [France]              NaN
# 32                                           [France]              NaN
#
#                           id                  geometry
# 0   4c84b599d92ea093f9785f72  POINT (1.44433 43.60413)
# 1   4c03b2459a7920a19230d079  POINT (1.44418 43.60452)
# 2   4b96adcbf964a52077dd34e3  POINT (1.44640 43.60117)
# 3   4bc1c05df8219c7456bbb310  POINT (1.43698 43.59564)
# 4   4df7a497fa76511d0048d1bb  POINT (1.43691 43.59635)
# 5   4b8a8935f964a520297132e3  POINT (1.44862 43.60425)
# 6   4c11328cce57c928cc1a83d2  POINT (1.44188 43.60041)
# 7   4b56353ef964a520570528e3  POINT (1.42907 43.60077)
# 8   4c28dafaed0ac9b6a9de60aa  POINT (1.45417 43.60001)
# 9   4c4c90cef7cc1b8df7a98041  POINT (1.44994 43.60421)
# 10  4c4718a1417b20a1a26edca9  POINT (1.43672 43.59883)
# 11  4b0e873af964a520495823e3  POINT (1.44947 43.59385)
# 12  4bf7fcdb4a67c928c07b24cf  POINT (1.45237 43.59599)
# 13  4bb74a63ef159c741ffb76f7  POINT (1.44672 43.60409)
# 14  4c42046fd7fad13a1f7508da  POINT (1.45569 43.60604)
# 15  4e60e005483bd9a9739fe231  POINT (1.45131 43.59703)
# 16  4cfaab427f2db1f752fa28d4  POINT (1.44105 43.61160)
# 17  4d8f3899d265236a566b1b17  POINT (1.44218 43.59772)
# 18  4bef186b96edc9b6e14c4af2  POINT (1.44111 43.60773)
# 19  4b5ac6d1f964a5202bd428e3  POINT (1.43537 43.61239)
# 20  4c0d40cf7189c928a9b8d6b6  POINT (1.44166 43.60691)
# 21  4c2219b911de20a1694684ce  POINT (1.44396 43.60919)
# 22  4bcdfb1f3aa6ef3bb9020f66  POINT (1.45655 43.60070)
# 23  4bb4ecbcb1edef3b9d4f2cdd  POINT (1.43706 43.60348)
# 24  4bdaf44463c5c9b64e982568  POINT (1.44425 43.60632)
# 25  502bd2f7e4b0a87aac740840  POINT (1.43691 43.59526)
# 26  4e2adec66284b96d7b80c02b  POINT (1.43079 43.60894)
# 27  4bf2d7af98ac0f47993462a8  POINT (1.43839 43.61177)
# 28  4d63817695b28cfa3bd94cfa  POINT (1.42538 43.60263)
# 29  4d8b0f870c422d43f57b0731  POINT (1.43127 43.61060)
# 30  4e00b47ccc3fe1394f70bc98  POINT (1.43475 43.61247)
# 31  4bc9c711cc8cd13a8f1abccf  POINT (1.42323 43.60632)
# 32  4f379e68e4b0a1f1970812d1  POINT (1.45634 43.59387)

# %%
import geopy.distance
dist = geopy.distance.geodesic( ( 43.60651,1.44569),(43.604130, 	1.444332))
dist.meters
# Out:
# 286.2575709868758

# %%
# from shapely.geometry import Point

# points = list()

# for lat, lng in zip(dataframe_filtered['lat'], dataframe_filtered['lng']):
#     points.append(Point(lng, lat))

# tls_cult_venue['geometry'] = geopandas.GeoSeries(points)

# tls_cult_venue.head()
# Out:
#                                     name  categories            address  \
# 0                    Théâtre du Capitole   spectacle  Place du Capitole
# 1  Hôtel de Ville de Toulouse (Capitole)    monument  Place du Capitole
# 2                    Musée des Augustins  exposition     21 Rue de Metz
# 3         Parc de la Prairie des Filtres        parc       Cours Dillon
# 4                               Rio Loco       music                NaN
#
#          lat       lng                                     labeledLatLngs  \
# 0  43.604130  1.444332  [{'label': 'display', 'lat': 43.60412979544746...
# 1  43.604523  1.444179  [{'label': 'display', 'lat': 43.60452250885116...
# 2  43.601170  1.446397  [{'label': 'display', 'lat': 43.6011697382502,...
# 3  43.595638  1.436977  [{'label': 'display', 'lat': 43.59563769241053...
# 4  43.596345  1.436907  [{'label': 'display', 'lat': 43.59634529848775...
#
#    distance postalCode  cc      city          state country  \
# 0       406      31000  FR  Toulouse  Midi-Pyrénées  France
# 1       429      31000  FR  Toulouse  Midi-Pyrénées  France
# 2       461      31000  FR  Toulouse  Midi-Pyrénées  France
# 3       728      31300  FR  Toulouse  Midi-Pyrénées  France
# 4       660        NaN  FR  Toulouse  Midi-Pyrénées  France
#
#                                     formattedAddress    crossStreet  \
# 0        [Place du Capitole, 31000 Toulouse, France]            NaN
# 1  [Place du Capitole (Rue Lafayette), 31000 Toul...  Rue Lafayette
# 2           [21 Rue de Metz, 31000 Toulouse, France]            NaN
# 3             [Cours Dillon, 31300 Toulouse, France]            NaN
# 4                                 [Toulouse, France]            NaN
#
#                          id                  geometry
# 0  4c84b599d92ea093f9785f72  POINT (1.44433 43.60413)
# 1  4c03b2459a7920a19230d079  POINT (1.44418 43.60452)
# 2  4b96adcbf964a52077dd34e3  POINT (1.44640 43.60117)
# 3  4bc1c05df8219c7456bbb310  POINT (1.43698 43.59564)
# 4  4df7a497fa76511d0048d1bb  POINT (1.43691 43.59635)
