# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>
#
# # Connect to Db2 database on Cloud using Python
#
# Estaimted time needed: **15** minutes
#
# ## Objectives
#
# After complting this lab you will be able to:
#
# -   Import the ibm_db Python library
# -   Enter the database connection credentials
# -   Create the database connection
# -   Close the database connection

# %% [markdown]
# **Note:** Please follow the instructions given in the first Lab of this course to Create a database service instance of Db2 on Cloud and retrieve your database Service Credentials.
#
# ## Import the `ibm_db` Python library
#
# The `ibm_db` [API ](https://pypi.python.org/pypi/ibm_db?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ) provides a variety of useful Python functions for accessing and manipulating data in an IBM® data server database, including functions for connecting to a database, preparing and issuing SQL statements, fetching rows from result sets, calling stored procedures, committing and rolling back transactions, handling errors, and retrieving metadata.
#
# We first import the ibm_db library into our Python Application
#
# Execute the following cell by clicking within it and then
# press `Shift` and `Enter` keys simultaneously

# %%
import ibm_db
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-fe3bb08c8a05> in <module>
# ----> 1 import ibm_db
#
# ModuleNotFoundError: No module named 'ibm_db'

# %%
# !pip install ibm-db
# Out:
# Collecting ibm-db
#   Using cached ibm_db-3.0.2.tar.gz (718 kB)
# Building wheels for collected packages: ibm-db
#   Building wheel for ibm-db (setup.py): started
#   Building wheel for ibm-db (setup.py): finished with status 'error'
#   Running setup.py clean for ibm-db
# Failed to build ibm-db
# Installing collected packages: ibm-db
#     Running setup.py install for ibm-db: started
#     Running setup.py install for ibm-db: finished with status 'error'
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\ProgramData\Anaconda3\envs\IBM\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Akim van Eersel\\AppData\\Local\\Temp\\pip-install-0yykipwf\\ibm-db\\setup.py'"'"'; __file__='"'"'C:\\Users\\Akim van Eersel\\AppData\\Local\\Temp\\pip-install-0yykipwf\\ibm-db\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\Akim van Eersel\AppData\Local\Temp\pip-wheel-9_9_1xyk'
#        cwd: C:\Users\Akim van Eersel\AppData\Local\Temp\pip-install-0yykipwf\ibm-db\
#   Complete output (363 lines):
#   Detected 64-bit Python
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.9
#   copying ibm_db_dbi.py -> build\lib.win-amd64-3.9
#   copying testfunctions.py -> build\lib.win-amd64-3.9
#   copying tests.py -> build\lib.win-amd64-3.9
#   creating build\lib.win-amd64-3.9\certs
#   copying certs\__init__.py -> build\lib.win-amd64-3.9\certs
#   creating build\lib.win-amd64-3.9\clidriver
#   copying clidriver\__init__.py -> build\lib.win-amd64-3.9\clidriver
#   creating build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_000_PrepareDb.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_001_ConnDb.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_002_ConnDbUncatalogedConn.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_003_NumAffectedRows.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_004_ConnWrongUserPwd.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_005_ConnBadUserBadPwd.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_006_ConnPassingOpts.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_007_pConnPassingOpts.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_008_ColumnInfo.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_010_UpdateRowCount.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_011_DeleteRowCount.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_012_KeysetDrivenCursorSelect01.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_013_KeysetDrivenCursorSelect02.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_014_KeysetDrivenCursorNegativeRow.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_015_InsertDeleteRowCount_01.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_016_InsertDeleteRowCount_02.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_017_selectRowcountPrefetchSTMTOpt.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_018_selectRowcountPrefetchSetOpt.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_019_selectRowcountPrefetchPrepOpt.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_020_RollbackDelete.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_021_CommitDelete.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_022_RollbackInsert.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_023_ColumnPrivileges.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_024_ForeignKeys.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_025_PrimaryKeys.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_030_Result.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_031_ResultIndexPosition.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_032_ResultIndexName.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_033_ResultOutSequenceColumn.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_034_FetchAssoc.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_035_FetchRow_01.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_036_FetchRow_02.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_037_FetchRowIndexPos.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_038_FetchRowIndexPosNested_01.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_039_FetchRowIndexPosNested_02.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_03a_ResultNonExistCol.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_040_FetchTuple.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_041_FetchTupleMany_01.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_042_FetchTupleMany_02.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_043_FetchTupleMany_03.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_044_FetchTupleMany_04.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_045_FetchTupleBinaryData_01.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_046_FetchTupleMany_05.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_047_FetchTupleMany_06.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_048_FetchTupleBinaryData_02.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_049_InsertNoneParam.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_050_AutocommitStatus.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_051_SetAutocommit_01.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_052_SetAutocommit_02.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_053_AttrThruConn.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_054_CursorType.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_060_Tables_01.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_061_Tables_02.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_062_Tables_03.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_063_Tables_04.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_064_Tables_05.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_065_FilterTableName.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_066_TableObjects.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_070_Close.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_071_CloseSuccess.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_080_ConnWrongDbAlias.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_081_ConnWrongUser.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_082_ConnWrongPwd.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_090_ConnmsgWrongDbAlias.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_091_ConnmsgWrongUser.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_092_ConnmsgWrongPwd.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_100_SelectDeleteInsertFieldCount.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_101_InsertDeleteFieldCount.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_102_NumFieldsSelect_01.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_103_NumFieldsSelect_02.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_110_FieldNum.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_111_FieldNumAddCol.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_112_FieldNumDiffCaseColNames.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_113_DateTest.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_114_NumericTest_01.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_115_NumericTest_02.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_116_ConnActive.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_120_FieldName.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_121_FieldNameAddCol.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_122_FieldNameDiffCaseColNames.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_123_FieldNamePos_01.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_124_FieldNamePos_02.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_125_FieldNamePos_03.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_130_PrepExecuteSelectStmt.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_131_PrepareExecuteSelectStatementParams.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_132_ExecuteStatementArrayMultipleParams.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_133_ExecuteLongInputParams.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_140_BindParamSelectStmt.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_141_BindParamSelectStmtMultipleParams_01.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_142_BindParamSelectStmtMultipleParams_02.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_143_BindParamInsertStmtNoneParam.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_144_BindParamInsertStmtPARAM_FILE.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_145_BindRetrieveNoneEmptyString.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_146_CallSPINAndOUTParams.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_147_PrepareWithWrongType.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_148_CallSPDiffBindPattern_01.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_150_FetchAssocSelect_01.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_151_FetchAssocSelect_02.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_152_FetchAssocSelect_03.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_153_FetchAssocSelect_04.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_154_AllFetches.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_155_FetchAssocSelect_05.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_156_FetchAssocNestedSelects_01.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_157a_FetchAssocWithoutScrollableCursorErr.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_157b_FetchAssocScrollableCursor_02.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_157_FetchAssocScrollableCursor_01.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_158_FetchAssocNestedSelects_02.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_159a_FetchAssocSeveralRows_02.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_159_FetchAssocSeveralRows_01.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_160_FetchBoth.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_161_FetchBothNestedSelects_01.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_162_FetchBothNestedSelects_02.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_180_StmtErrMsg.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_190_ColumnsTable_01.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_191_ColumnsTable_02.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_195_InsertRetrieveXMLData_01.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_196_InsertRetrieveXMLData_02.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_197_StatisticsIndexes.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_200_MultipleRsltsetsUniformColDefs.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_201_MultipleRsltsetsDiffColDefs.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_210_FieldDisplaySize_01.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_211_FieldDisplaySize_02.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_212_FieldDisplaySize_03.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_213_FieldDisplaySize_04.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_220_PersistentConn.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_221_100PersistentConns.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_230_FieldTypePos.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_231_FieldTypeName.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_232_FieldTypePosName.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_240_FieldWidthPosName_01.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_241_FieldWidthPosName_02.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_250_FreeResult_01.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_251_FreeResult_02.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_260_FetchTupleMany_07.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_261_FetchObjectAccess.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_264_InsertRetrieveBIGINTTypeColumn.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_265_NoAffectedRows.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_300_ServerInfo.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_310_ClientInfo.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_311_InsertSelectDeleteNumLiterals.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_52949_TestSPIntVarcharXml.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_6528_ScopingProblemBindParam.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_6561_InsertNULLValues.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_6755_ExtraNULLChar_ResultCLOBCol.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_6792_FieldTypeRetStrDatetimeTimestamp.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_booleanInsertSelect.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_createdbNX.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_createDropDB.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_cursortype.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_decfloat.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_decimal.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_err_executemany.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_execute_many.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_InsertRetrieveDateTimeTypeColumn.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_recreateDB.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_setgetOption.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_SPInOutBlob.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_SPInOutZero.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_trusted_context_connect.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_trusted_context_pconnect.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\test_warn.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   copying ibm_db_tests\__init__.py -> build\lib.win-amd64-3.9\ibm_db_tests
#   running egg_info
#   writing ibm_db.egg-info\PKG-INFO
#   writing dependency_links to ibm_db.egg-info\dependency_links.txt
#   writing top-level names to ibm_db.egg-info\top_level.txt
#   reading manifest file 'ibm_db.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no files found matching '*.png' under directory 'ibm_db_tests'
#   warning: no files found matching '*.jpg' under directory 'ibm_db_tests'
#   warning: no files found matching '*' under directory 'ibm_db_dlls'
#   warning: no previously-included files found matching 'config.py'
#   writing manifest file 'ibm_db.egg-info\SOURCES.txt'
#   copying certs\ibm_certs.pem -> build\lib.win-amd64-3.9\certs
#   creating build\lib.win-amd64-3.9\clidriver\bin
#   copying clidriver\bin\DB2xml4c_cli64_5_8.dll -> build\lib.win-amd64-3.9\clidriver\bin
#   copying clidriver\bin\DB2xml4c_cli64_5_8.dll.2.manifest -> build\lib.win-amd64-3.9\clidriver\bin
#   copying clidriver\bin\IBM.DB2.APP64.manifest -> build\lib.win-amd64-3.9\clidriver\bin
#   copying clidriver\bin\IBM.DB2.CLI64.manifest -> build\lib.win-amd64-3.9\clidriver\bin
#   copying clidriver\bin\IBM.DB2.CLIXML4C64.manifest -> build\lib.win-amd64-3.9\clidriver\bin
#   copying clidriver\bin\IBM.DB2.LDAP64.manifest -> build\lib.win-amd64-3.9\clidriver\bin
#   copying clidriver\bin\IBM.DB2.LDAPM64.manifest -> build\lib.win-amd64-3.9\clidriver\bin
#   copying clidriver\bin\IBM.DB2.SEC64.manifest -> build\lib.win-amd64-3.9\clidriver\bin
#   copying clidriver\bin\IBMIAMauth64.dll -> build\lib.win-amd64-3.9\clidriver\bin
#   copying clidriver\bin\IBMLDAPauthclient64.dll -> build\lib.win-amd64-3.9\clidriver\bin
#   copying clidriver\bin\IBMOSauthclient64.dll -> build\lib.win-amd64-3.9\clidriver\bin
#   copying clidriver\bin\IBMOSauthclientTwoPart64.dll -> build\lib.win-amd64-3.9\clidriver\bin
#   copying clidriver\bin\IBMkrb564.dll -> build\lib.win-amd64-3.9\clidriver\bin
#   copying clidriver\bin\IBMkrb5TwoPart64.dll -> build\lib.win-amd64-3.9\clidriver\bin
#   copying clidriver\bin\db2app64.dll -> build\lib.win-amd64-3.9\clidriver\bin
#   copying clidriver\bin\db2cli.exe -> build\lib.win-amd64-3.9\clidriver\bin
#   copying clidriver\bin\db2cli64.dll -> build\lib.win-amd64-3.9\clidriver\bin
#   copying clidriver\bin\db2clixml4c64.dll -> build\lib.win-amd64-3.9\clidriver\bin
#   copying clidriver\bin\db2ldap64.dll -> build\lib.win-amd64-3.9\clidriver\bin
#   copying clidriver\bin\db2ldapm64.dll -> build\lib.win-amd64-3.9\clidriver\bin
#   copying clidriver\bin\db2level.exe -> build\lib.win-amd64-3.9\clidriver\bin
#   copying clidriver\bin\db2osse64.dll -> build\lib.win-amd64-3.9\clidriver\bin
#   copying clidriver\bin\db2support.exe -> build\lib.win-amd64-3.9\clidriver\bin
#   copying clidriver\bin\db2trc.exe -> build\lib.win-amd64-3.9\clidriver\bin
#   copying clidriver\bin\db2trcapi64.dll -> build\lib.win-amd64-3.9\clidriver\bin
#   copying clidriver\bin\db2trcd64.exe -> build\lib.win-amd64-3.9\clidriver\bin
#   copying clidriver\bin\ibmdadb264.dll -> build\lib.win-amd64-3.9\clidriver\bin
#   creating build\lib.win-amd64-3.9\clidriver\bin\amd64.VC12.CRT
#   copying clidriver\bin\amd64.VC12.CRT\amd64.VC12.CRT.manifest -> build\lib.win-amd64-3.9\clidriver\bin\amd64.VC12.CRT
#   copying clidriver\bin\amd64.VC12.CRT\msvcp120.dll -> build\lib.win-amd64-3.9\clidriver\bin\amd64.VC12.CRT
#   copying clidriver\bin\amd64.VC12.CRT\msvcr120.dll -> build\lib.win-amd64-3.9\clidriver\bin\amd64.VC12.CRT
#   creating build\lib.win-amd64-3.9\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8cms_64.dll -> build\lib.win-amd64-3.9\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8dbfl_64.dll -> build\lib.win-amd64-3.9\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8iccs_64.dll -> build\lib.win-amd64-3.9\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8kicc_64.dll -> build\lib.win-amd64-3.9\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8km_64.dll -> build\lib.win-amd64-3.9\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8msca_64.dll -> build\lib.win-amd64-3.9\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8ssl_64.dll -> build\lib.win-amd64-3.9\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8sys_64.dll -> build\lib.win-amd64-3.9\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8valn_64.dll -> build\lib.win-amd64-3.9\clidriver\bin\icc64
#   creating build\lib.win-amd64-3.9\clidriver\bin\icc64\c
#   creating build\lib.win-amd64-3.9\clidriver\bin\icc64\c\icc
#   copying clidriver\bin\icc64\c\icc\ReadMe.txt -> build\lib.win-amd64-3.9\clidriver\bin\icc64\c\icc
#   creating build\lib.win-amd64-3.9\clidriver\bin\icc64\c\icc\icclib
#   copying clidriver\bin\icc64\c\icc\icclib\ICCSIG.txt -> build\lib.win-amd64-3.9\clidriver\bin\icc64\c\icc\icclib
#   copying clidriver\bin\icc64\c\icc\icclib\icclib084.dll -> build\lib.win-amd64-3.9\clidriver\bin\icc64\c\icc\icclib
#   creating build\lib.win-amd64-3.9\clidriver\bin\icc64\n
#   creating build\lib.win-amd64-3.9\clidriver\bin\icc64\n\icc
#   copying clidriver\bin\icc64\n\icc\ReadMe.txt -> build\lib.win-amd64-3.9\clidriver\bin\icc64\n\icc
#   creating build\lib.win-amd64-3.9\clidriver\bin\icc64\n\icc\icclib
#   copying clidriver\bin\icc64\n\icc\icclib\ICCSIG.txt -> build\lib.win-amd64-3.9\clidriver\bin\icc64\n\icc\icclib
#   copying clidriver\bin\icc64\n\icc\icclib\icclib085.dll -> build\lib.win-amd64-3.9\clidriver\bin\icc64\n\icc\icclib
#   creating build\lib.win-amd64-3.9\clidriver\bnd
#   copying clidriver\bnd\db2ajgrt.bnd -> build\lib.win-amd64-3.9\clidriver\bnd
#   copying clidriver\bnd\db2cli.bnd -> build\lib.win-amd64-3.9\clidriver\bnd
#   copying clidriver\bnd\db2cli.lst -> build\lib.win-amd64-3.9\clidriver\bnd
#   copying clidriver\bnd\db2clipk.bnd -> build\lib.win-amd64-3.9\clidriver\bnd
#   copying clidriver\bnd\db2clist.bnd -> build\lib.win-amd64-3.9\clidriver\bnd
#   copying clidriver\bnd\db2spcdb.bnd -> build\lib.win-amd64-3.9\clidriver\bnd
#   creating build\lib.win-amd64-3.9\clidriver\cfg
#   copying clidriver\cfg\DigiCertGlobalRootCA.arm -> build\lib.win-amd64-3.9\clidriver\cfg
#   copying clidriver\cfg\db2dsdriver.xsd -> build\lib.win-amd64-3.9\clidriver\cfg
#   creating build\lib.win-amd64-3.9\clidriver\conv
#   creating build\lib.win-amd64-3.9\clidriver\conv\alt
#   copying clidriver\conv\alt\04370923.cnv -> build\lib.win-amd64-3.9\clidriver\conv\alt
#   copying clidriver\conv\alt\08500923.cnv -> build\lib.win-amd64-3.9\clidriver\conv\alt
#   copying clidriver\conv\alt\08501252.cnv -> build\lib.win-amd64-3.9\clidriver\conv\alt
#   copying clidriver\conv\alt\08600923.cnv -> build\lib.win-amd64-3.9\clidriver\conv\alt
#   copying clidriver\conv\alt\08630923.cnv -> build\lib.win-amd64-3.9\clidriver\conv\alt
#   copying clidriver\conv\alt\09230437.cnv -> build\lib.win-amd64-3.9\clidriver\conv\alt
#   copying clidriver\conv\alt\09230850.cnv -> build\lib.win-amd64-3.9\clidriver\conv\alt
#   copying clidriver\conv\alt\09230860.cnv -> build\lib.win-amd64-3.9\clidriver\conv\alt
#   copying clidriver\conv\alt\09231043.cnv -> build\lib.win-amd64-3.9\clidriver\conv\alt
#   copying clidriver\conv\alt\09231051.cnv -> build\lib.win-amd64-3.9\clidriver\conv\alt
#   copying clidriver\conv\alt\09231114.cnv -> build\lib.win-amd64-3.9\clidriver\conv\alt
#   copying clidriver\conv\alt\09231208.cnv -> build\lib.win-amd64-3.9\clidriver\conv\alt
#   copying clidriver\conv\alt\09231252.cnv -> build\lib.win-amd64-3.9\clidriver\conv\alt
#   copying clidriver\conv\alt\09231275.cnv -> build\lib.win-amd64-3.9\clidriver\conv\alt
#   copying clidriver\conv\alt\09241252.cnv -> build\lib.win-amd64-3.9\clidriver\conv\alt
#   copying clidriver\conv\alt\09370950.cnv -> build\lib.win-amd64-3.9\clidriver\conv\alt
#   copying clidriver\conv\alt\10430923.cnv -> build\lib.win-amd64-3.9\clidriver\conv\alt
#   copying clidriver\conv\alt\10510923.cnv -> build\lib.win-amd64-3.9\clidriver\conv\alt
#   copying clidriver\conv\alt\11140923.cnv -> build\lib.win-amd64-3.9\clidriver\conv\alt
#   copying clidriver\conv\alt\12080923.cnv -> build\lib.win-amd64-3.9\clidriver\conv\alt
#   copying clidriver\conv\alt\12520850.cnv -> build\lib.win-amd64-3.9\clidriver\conv\alt
#   copying clidriver\conv\alt\12520923.cnv -> build\lib.win-amd64-3.9\clidriver\conv\alt
#   copying clidriver\conv\alt\12750923.cnv -> build\lib.win-amd64-3.9\clidriver\conv\alt
#   copying clidriver\conv\alt\1388ucs2.cnv -> build\lib.win-amd64-3.9\clidriver\conv\alt
#   copying clidriver\conv\alt\IBM00850.ucs -> build\lib.win-amd64-3.9\clidriver\conv\alt
#   copying clidriver\conv\alt\IBM00923.ucs -> build\lib.win-amd64-3.9\clidriver\conv\alt
#   copying clidriver\conv\alt\IBM01252.ucs -> build\lib.win-amd64-3.9\clidriver\conv\alt
#   creating build\lib.win-amd64-3.9\clidriver\conv\ms
#   copying clidriver\conv\ms\0930ucs2.cnv -> build\lib.win-amd64-3.9\clidriver\conv\ms
#   copying clidriver\conv\ms\0939ucs2.cnv -> build\lib.win-amd64-3.9\clidriver\conv\ms
#   copying clidriver\conv\ms\0943ucs2.cnv -> build\lib.win-amd64-3.9\clidriver\conv\ms
#   copying clidriver\conv\ms\0954ucs2.cnv -> build\lib.win-amd64-3.9\clidriver\conv\ms
#   copying clidriver\conv\ms\1390ucs2.cnv -> build\lib.win-amd64-3.9\clidriver\conv\ms
#   copying clidriver\conv\ms\1399ucs2.cnv -> build\lib.win-amd64-3.9\clidriver\conv\ms
#   copying clidriver\conv\ms\5039ucs2.cnv -> build\lib.win-amd64-3.9\clidriver\conv\ms
#   copying clidriver\conv\ms\ucs20943.cnv -> build\lib.win-amd64-3.9\clidriver\conv\ms
#   creating build\lib.win-amd64-3.9\clidriver\db2
#   copying clidriver\db2\db2diag.log -> build\lib.win-amd64-3.9\clidriver\db2
#   creating build\lib.win-amd64-3.9\clidriver\include
#   copying clidriver\include\sql.h -> build\lib.win-amd64-3.9\clidriver\include
#   copying clidriver\include\sqlca.h -> build\lib.win-amd64-3.9\clidriver\include
#   copying clidriver\include\sqlcli.h -> build\lib.win-amd64-3.9\clidriver\include
#   copying clidriver\include\sqlcli1.h -> build\lib.win-amd64-3.9\clidriver\include
#   copying clidriver\include\sqlda.h -> build\lib.win-amd64-3.9\clidriver\include
#   copying clidriver\include\sqlenv.h -> build\lib.win-amd64-3.9\clidriver\include
#   copying clidriver\include\sqlext.h -> build\lib.win-amd64-3.9\clidriver\include
#   copying clidriver\include\sqlstate.h -> build\lib.win-amd64-3.9\clidriver\include
#   copying clidriver\include\sqlsystm.h -> build\lib.win-amd64-3.9\clidriver\include
#   copying clidriver\include\sqltypes.h -> build\lib.win-amd64-3.9\clidriver\include
#   copying clidriver\include\sqlucode.h -> build\lib.win-amd64-3.9\clidriver\include
#   copying clidriver\include\sqlunx.h -> build\lib.win-amd64-3.9\clidriver\include
#   creating build\lib.win-amd64-3.9\clidriver\lib
#   copying clidriver\lib\db2app64.lib -> build\lib.win-amd64-3.9\clidriver\lib
#   copying clidriver\lib\db2cli64.lib -> build\lib.win-amd64-3.9\clidriver\lib
#   creating build\lib.win-amd64-3.9\clidriver\license
#   copying clidriver\license\odbc_REDIST.txt -> build\lib.win-amd64-3.9\clidriver\license
#   copying clidriver\license\odbc_notices.rtf -> build\lib.win-amd64-3.9\clidriver\license
#   creating build\lib.win-amd64-3.9\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_br.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_cn.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_cz.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_de.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_el.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_en.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_es.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_fr.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_in.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_it.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_jp.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_kr.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_lt.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_pl.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_ru.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_sl.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_tr.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_tw.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#   creating build\lib.win-amd64-3.9\clidriver\msg
#   creating build\lib.win-amd64-3.9\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2adm.mo -> build\lib.win-amd64-3.9\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2admh.mo -> build\lib.win-amd64-3.9\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2caem.mo -> build\lib.win-amd64-3.9\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2cklog.mo -> build\lib.win-amd64-3.9\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2cli.mo -> build\lib.win-amd64-3.9\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2clia1.lst -> build\lib.win-amd64-3.9\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2clias.lst -> build\lib.win-amd64-3.9\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2clih.mo -> build\lib.win-amd64-3.9\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2clit.mo -> build\lib.win-amd64-3.9\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2clp.mo -> build\lib.win-amd64-3.9\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2clp2.mo -> build\lib.win-amd64-3.9\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2fodc.mo -> build\lib.win-amd64-3.9\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2sql.mo -> build\lib.win-amd64-3.9\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2sqlh.mo -> build\lib.win-amd64-3.9\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2stt.mo -> build\lib.win-amd64-3.9\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2supp.mo -> build\lib.win-amd64-3.9\clidriver\msg\en_US
#   C:\ProgramData\Anaconda3\envs\IBM\lib\site-packages\setuptools\lib2to3_ex.py:36: SetuptoolsDeprecationWarning: 2to3 support is deprecated. If the project still requires Python 2 support, please migrate to a single-codebase solution or employ an independent conversion process.
#     warnings.warn(
#   Fixing build\lib.win-amd64-3.9\ibm_db_dbi.py build\lib.win-amd64-3.9\testfunctions.py build\lib.win-amd64-3.9\tests.py build\lib.win-amd64-3.9\certs\__init__.py build\lib.win-amd64-3.9\clidriver\__init__.py build\lib.win-amd64-3.9\ibm_db_tests\test_000_PrepareDb.py build\lib.win-amd64-3.9\ibm_db_tests\test_001_ConnDb.py build\lib.win-amd64-3.9\ibm_db_tests\test_002_ConnDbUncatalogedConn.py build\lib.win-amd64-3.9\ibm_db_tests\test_003_NumAffectedRows.py build\lib.win-amd64-3.9\ibm_db_tests\test_004_ConnWrongUserPwd.py build\lib.win-amd64-3.9\ibm_db_tests\test_005_ConnBadUserBadPwd.py build\lib.win-amd64-3.9\ibm_db_tests\test_006_ConnPassingOpts.py build\lib.win-amd64-3.9\ibm_db_tests\test_007_pConnPassingOpts.py build\lib.win-amd64-3.9\ibm_db_tests\test_008_ColumnInfo.py build\lib.win-amd64-3.9\ibm_db_tests\test_010_UpdateRowCount.py build\lib.win-amd64-3.9\ibm_db_tests\test_011_DeleteRowCount.py build\lib.win-amd64-3.9\ibm_db_tests\test_012_KeysetDrivenCursorSelect01.py build\lib.win-amd64-3.9\ibm_db_tests\test_013_KeysetDrivenCursorSelect02.py build\lib.win-amd64-3.9\ibm_db_tests\test_014_KeysetDrivenCursorNegativeRow.py build\lib.win-amd64-3.9\ibm_db_tests\test_015_InsertDeleteRowCount_01.py build\lib.win-amd64-3.9\ibm_db_tests\test_016_InsertDeleteRowCount_02.py build\lib.win-amd64-3.9\ibm_db_tests\test_017_selectRowcountPrefetchSTMTOpt.py build\lib.win-amd64-3.9\ibm_db_tests\test_018_selectRowcountPrefetchSetOpt.py build\lib.win-amd64-3.9\ibm_db_tests\test_019_selectRowcountPrefetchPrepOpt.py build\lib.win-amd64-3.9\ibm_db_tests\test_020_RollbackDelete.py build\lib.win-amd64-3.9\ibm_db_tests\test_021_CommitDelete.py build\lib.win-amd64-3.9\ibm_db_tests\test_022_RollbackInsert.py build\lib.win-amd64-3.9\ibm_db_tests\test_023_ColumnPrivileges.py build\lib.win-amd64-3.9\ibm_db_tests\test_024_ForeignKeys.py build\lib.win-amd64-3.9\ibm_db_tests\test_025_PrimaryKeys.py build\lib.win-amd64-3.9\ibm_db_tests\test_030_Result.py build\lib.win-amd64-3.9\ibm_db_tests\test_031_ResultIndexPosition.py build\lib.win-amd64-3.9\ibm_db_tests\test_032_ResultIndexName.py build\lib.win-amd64-3.9\ibm_db_tests\test_033_ResultOutSequenceColumn.py build\lib.win-amd64-3.9\ibm_db_tests\test_034_FetchAssoc.py build\lib.win-amd64-3.9\ibm_db_tests\test_035_FetchRow_01.py build\lib.win-amd64-3.9\ibm_db_tests\test_036_FetchRow_02.py build\lib.win-amd64-3.9\ibm_db_tests\test_037_FetchRowIndexPos.py build\lib.win-amd64-3.9\ibm_db_tests\test_038_FetchRowIndexPosNested_01.py build\lib.win-amd64-3.9\ibm_db_tests\test_039_FetchRowIndexPosNested_02.py build\lib.win-amd64-3.9\ibm_db_tests\test_03a_ResultNonExistCol.py build\lib.win-amd64-3.9\ibm_db_tests\test_040_FetchTuple.py build\lib.win-amd64-3.9\ibm_db_tests\test_041_FetchTupleMany_01.py build\lib.win-amd64-3.9\ibm_db_tests\test_042_FetchTupleMany_02.py build\lib.win-amd64-3.9\ibm_db_tests\test_043_FetchTupleMany_03.py build\lib.win-amd64-3.9\ibm_db_tests\test_044_FetchTupleMany_04.py build\lib.win-amd64-3.9\ibm_db_tests\test_045_FetchTupleBinaryData_01.py build\lib.win-amd64-3.9\ibm_db_tests\test_046_FetchTupleMany_05.py build\lib.win-amd64-3.9\ibm_db_tests\test_047_FetchTupleMany_06.py build\lib.win-amd64-3.9\ibm_db_tests\test_048_FetchTupleBinaryData_02.py build\lib.win-amd64-3.9\ibm_db_tests\test_049_InsertNoneParam.py build\lib.win-amd64-3.9\ibm_db_tests\test_050_AutocommitStatus.py build\lib.win-amd64-3.9\ibm_db_tests\test_051_SetAutocommit_01.py build\lib.win-amd64-3.9\ibm_db_tests\test_052_SetAutocommit_02.py build\lib.win-amd64-3.9\ibm_db_tests\test_053_AttrThruConn.py build\lib.win-amd64-3.9\ibm_db_tests\test_054_CursorType.py build\lib.win-amd64-3.9\ibm_db_tests\test_060_Tables_01.py build\lib.win-amd64-3.9\ibm_db_tests\test_061_Tables_02.py build\lib.win-amd64-3.9\ibm_db_tests\test_062_Tables_03.py build\lib.win-amd64-3.9\ibm_db_tests\test_063_Tables_04.py build\lib.win-amd64-3.9\ibm_db_tests\test_064_Tables_05.py build\lib.win-amd64-3.9\ibm_db_tests\test_065_FilterTableName.py build\lib.win-am ...
#   Skipping optional fixer: buffer
#   Skipping optional fixer: idioms
#   Skipping optional fixer: set_literal
#   Skipping optional fixer: ws_comma
#   Fixing build\lib.win-amd64-3.9\ibm_db_dbi.py build\lib.win-amd64-3.9\testfunctions.py build\lib.win-amd64-3.9\tests.py build\lib.win-amd64-3.9\certs\__init__.py build\lib.win-amd64-3.9\clidriver\__init__.py build\lib.win-amd64-3.9\ibm_db_tests\test_000_PrepareDb.py build\lib.win-amd64-3.9\ibm_db_tests\test_001_ConnDb.py build\lib.win-amd64-3.9\ibm_db_tests\test_002_ConnDbUncatalogedConn.py build\lib.win-amd64-3.9\ibm_db_tests\test_003_NumAffectedRows.py build\lib.win-amd64-3.9\ibm_db_tests\test_004_ConnWrongUserPwd.py build\lib.win-amd64-3.9\ibm_db_tests\test_005_ConnBadUserBadPwd.py build\lib.win-amd64-3.9\ibm_db_tests\test_006_ConnPassingOpts.py build\lib.win-amd64-3.9\ibm_db_tests\test_007_pConnPassingOpts.py build\lib.win-amd64-3.9\ibm_db_tests\test_008_ColumnInfo.py build\lib.win-amd64-3.9\ibm_db_tests\test_010_UpdateRowCount.py build\lib.win-amd64-3.9\ibm_db_tests\test_011_DeleteRowCount.py build\lib.win-amd64-3.9\ibm_db_tests\test_012_KeysetDrivenCursorSelect01.py build\lib.win-amd64-3.9\ibm_db_tests\test_013_KeysetDrivenCursorSelect02.py build\lib.win-amd64-3.9\ibm_db_tests\test_014_KeysetDrivenCursorNegativeRow.py build\lib.win-amd64-3.9\ibm_db_tests\test_015_InsertDeleteRowCount_01.py build\lib.win-amd64-3.9\ibm_db_tests\test_016_InsertDeleteRowCount_02.py build\lib.win-amd64-3.9\ibm_db_tests\test_017_selectRowcountPrefetchSTMTOpt.py build\lib.win-amd64-3.9\ibm_db_tests\test_018_selectRowcountPrefetchSetOpt.py build\lib.win-amd64-3.9\ibm_db_tests\test_019_selectRowcountPrefetchPrepOpt.py build\lib.win-amd64-3.9\ibm_db_tests\test_020_RollbackDelete.py build\lib.win-amd64-3.9\ibm_db_tests\test_021_CommitDelete.py build\lib.win-amd64-3.9\ibm_db_tests\test_022_RollbackInsert.py build\lib.win-amd64-3.9\ibm_db_tests\test_023_ColumnPrivileges.py build\lib.win-amd64-3.9\ibm_db_tests\test_024_ForeignKeys.py build\lib.win-amd64-3.9\ibm_db_tests\test_025_PrimaryKeys.py build\lib.win-amd64-3.9\ibm_db_tests\test_030_Result.py build\lib.win-amd64-3.9\ibm_db_tests\test_031_ResultIndexPosition.py build\lib.win-amd64-3.9\ibm_db_tests\test_032_ResultIndexName.py build\lib.win-amd64-3.9\ibm_db_tests\test_033_ResultOutSequenceColumn.py build\lib.win-amd64-3.9\ibm_db_tests\test_034_FetchAssoc.py build\lib.win-amd64-3.9\ibm_db_tests\test_035_FetchRow_01.py build\lib.win-amd64-3.9\ibm_db_tests\test_036_FetchRow_02.py build\lib.win-amd64-3.9\ibm_db_tests\test_037_FetchRowIndexPos.py build\lib.win-amd64-3.9\ibm_db_tests\test_038_FetchRowIndexPosNested_01.py build\lib.win-amd64-3.9\ibm_db_tests\test_039_FetchRowIndexPosNested_02.py build\lib.win-amd64-3.9\ibm_db_tests\test_03a_ResultNonExistCol.py build\lib.win-amd64-3.9\ibm_db_tests\test_040_FetchTuple.py build\lib.win-amd64-3.9\ibm_db_tests\test_041_FetchTupleMany_01.py build\lib.win-amd64-3.9\ibm_db_tests\test_042_FetchTupleMany_02.py build\lib.win-amd64-3.9\ibm_db_tests\test_043_FetchTupleMany_03.py build\lib.win-amd64-3.9\ibm_db_tests\test_044_FetchTupleMany_04.py build\lib.win-amd64-3.9\ibm_db_tests\test_045_FetchTupleBinaryData_01.py build\lib.win-amd64-3.9\ibm_db_tests\test_046_FetchTupleMany_05.py build\lib.win-amd64-3.9\ibm_db_tests\test_047_FetchTupleMany_06.py build\lib.win-amd64-3.9\ibm_db_tests\test_048_FetchTupleBinaryData_02.py build\lib.win-amd64-3.9\ibm_db_tests\test_049_InsertNoneParam.py build\lib.win-amd64-3.9\ibm_db_tests\test_050_AutocommitStatus.py build\lib.win-amd64-3.9\ibm_db_tests\test_051_SetAutocommit_01.py build\lib.win-amd64-3.9\ibm_db_tests\test_052_SetAutocommit_02.py build\lib.win-amd64-3.9\ibm_db_tests\test_053_AttrThruConn.py build\lib.win-amd64-3.9\ibm_db_tests\test_054_CursorType.py build\lib.win-amd64-3.9\ibm_db_tests\test_060_Tables_01.py build\lib.win-amd64-3.9\ibm_db_tests\test_061_Tables_02.py build\lib.win-amd64-3.9\ibm_db_tests\test_062_Tables_03.py build\lib.win-amd64-3.9\ibm_db_tests\test_063_Tables_04.py build\lib.win-amd64-3.9\ibm_db_tests\test_064_Tables_05.py build\lib.win-amd64-3.9\ibm_db_tests\test_065_FilterTableName.py build\lib.win-am ...
#   Skipping optional fixer: buffer
#   Skipping optional fixer: idioms
#   Skipping optional fixer: set_literal
#   Skipping optional fixer: ws_comma
#   running build_ext
#   building 'ibm_db' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for ibm-db
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\ProgramData\Anaconda3\envs\IBM\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Akim van Eersel\\AppData\\Local\\Temp\\pip-install-0yykipwf\\ibm-db\\setup.py'"'"'; __file__='"'"'C:\\Users\\Akim van Eersel\\AppData\\Local\\Temp\\pip-install-0yykipwf\\ibm-db\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Akim van Eersel\AppData\Local\Temp\pip-record-5237twbo\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\ProgramData\Anaconda3\envs\IBM\Include\ibm-db'
#          cwd: C:\Users\Akim van Eersel\AppData\Local\Temp\pip-install-0yykipwf\ibm-db\
#     Complete output (363 lines):
#     Detected 64-bit Python
#     running install
#     running build
#     running build_py
#     creating build
#     creating build\lib.win-amd64-3.9
#     copying ibm_db_dbi.py -> build\lib.win-amd64-3.9
#     copying testfunctions.py -> build\lib.win-amd64-3.9
#     copying tests.py -> build\lib.win-amd64-3.9
#     creating build\lib.win-amd64-3.9\certs
#     copying certs\__init__.py -> build\lib.win-amd64-3.9\certs
#     creating build\lib.win-amd64-3.9\clidriver
#     copying clidriver\__init__.py -> build\lib.win-amd64-3.9\clidriver
#     creating build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_000_PrepareDb.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_001_ConnDb.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_002_ConnDbUncatalogedConn.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_003_NumAffectedRows.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_004_ConnWrongUserPwd.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_005_ConnBadUserBadPwd.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_006_ConnPassingOpts.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_007_pConnPassingOpts.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_008_ColumnInfo.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_010_UpdateRowCount.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_011_DeleteRowCount.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_012_KeysetDrivenCursorSelect01.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_013_KeysetDrivenCursorSelect02.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_014_KeysetDrivenCursorNegativeRow.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_015_InsertDeleteRowCount_01.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_016_InsertDeleteRowCount_02.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_017_selectRowcountPrefetchSTMTOpt.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_018_selectRowcountPrefetchSetOpt.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_019_selectRowcountPrefetchPrepOpt.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_020_RollbackDelete.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_021_CommitDelete.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_022_RollbackInsert.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_023_ColumnPrivileges.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_024_ForeignKeys.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_025_PrimaryKeys.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_030_Result.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_031_ResultIndexPosition.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_032_ResultIndexName.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_033_ResultOutSequenceColumn.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_034_FetchAssoc.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_035_FetchRow_01.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_036_FetchRow_02.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_037_FetchRowIndexPos.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_038_FetchRowIndexPosNested_01.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_039_FetchRowIndexPosNested_02.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_03a_ResultNonExistCol.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_040_FetchTuple.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_041_FetchTupleMany_01.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_042_FetchTupleMany_02.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_043_FetchTupleMany_03.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_044_FetchTupleMany_04.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_045_FetchTupleBinaryData_01.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_046_FetchTupleMany_05.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_047_FetchTupleMany_06.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_048_FetchTupleBinaryData_02.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_049_InsertNoneParam.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_050_AutocommitStatus.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_051_SetAutocommit_01.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_052_SetAutocommit_02.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_053_AttrThruConn.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_054_CursorType.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_060_Tables_01.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_061_Tables_02.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_062_Tables_03.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_063_Tables_04.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_064_Tables_05.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_065_FilterTableName.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_066_TableObjects.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_070_Close.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_071_CloseSuccess.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_080_ConnWrongDbAlias.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_081_ConnWrongUser.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_082_ConnWrongPwd.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_090_ConnmsgWrongDbAlias.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_091_ConnmsgWrongUser.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_092_ConnmsgWrongPwd.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_100_SelectDeleteInsertFieldCount.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_101_InsertDeleteFieldCount.py -> build\lib.win-amd64-3.9\ibm_db_tests
#     copying ibm_db_tests\test_102_NumFieldsSelect_01.py -> build\lib.win-amd64-3.9\ibm_db_tests
# ...
#     copying clidriver\conv\alt\1388ucs2.cnv -> build\lib.win-amd64-3.9\clidriver\conv\alt
#     copying clidriver\conv\alt\IBM00850.ucs -> build\lib.win-amd64-3.9\clidriver\conv\alt
#     copying clidriver\conv\alt\IBM00923.ucs -> build\lib.win-amd64-3.9\clidriver\conv\alt
#     copying clidriver\conv\alt\IBM01252.ucs -> build\lib.win-amd64-3.9\clidriver\conv\alt
#     creating build\lib.win-amd64-3.9\clidriver\conv\ms
#     copying clidriver\conv\ms\0930ucs2.cnv -> build\lib.win-amd64-3.9\clidriver\conv\ms
#     copying clidriver\conv\ms\0939ucs2.cnv -> build\lib.win-amd64-3.9\clidriver\conv\ms
#     copying clidriver\conv\ms\0943ucs2.cnv -> build\lib.win-amd64-3.9\clidriver\conv\ms
#     copying clidriver\conv\ms\0954ucs2.cnv -> build\lib.win-amd64-3.9\clidriver\conv\ms
#     copying clidriver\conv\ms\1390ucs2.cnv -> build\lib.win-amd64-3.9\clidriver\conv\ms
#     copying clidriver\conv\ms\1399ucs2.cnv -> build\lib.win-amd64-3.9\clidriver\conv\ms
#     copying clidriver\conv\ms\5039ucs2.cnv -> build\lib.win-amd64-3.9\clidriver\conv\ms
#     copying clidriver\conv\ms\ucs20943.cnv -> build\lib.win-amd64-3.9\clidriver\conv\ms
#     creating build\lib.win-amd64-3.9\clidriver\db2
#     copying clidriver\db2\db2diag.log -> build\lib.win-amd64-3.9\clidriver\db2
#     creating build\lib.win-amd64-3.9\clidriver\include
#     copying clidriver\include\sql.h -> build\lib.win-amd64-3.9\clidriver\include
#     copying clidriver\include\sqlca.h -> build\lib.win-amd64-3.9\clidriver\include
#     copying clidriver\include\sqlcli.h -> build\lib.win-amd64-3.9\clidriver\include
#     copying clidriver\include\sqlcli1.h -> build\lib.win-amd64-3.9\clidriver\include
#     copying clidriver\include\sqlda.h -> build\lib.win-amd64-3.9\clidriver\include
#     copying clidriver\include\sqlenv.h -> build\lib.win-amd64-3.9\clidriver\include
#     copying clidriver\include\sqlext.h -> build\lib.win-amd64-3.9\clidriver\include
#     copying clidriver\include\sqlstate.h -> build\lib.win-amd64-3.9\clidriver\include
#     copying clidriver\include\sqlsystm.h -> build\lib.win-amd64-3.9\clidriver\include
#     copying clidriver\include\sqltypes.h -> build\lib.win-amd64-3.9\clidriver\include
#     copying clidriver\include\sqlucode.h -> build\lib.win-amd64-3.9\clidriver\include
#     copying clidriver\include\sqlunx.h -> build\lib.win-amd64-3.9\clidriver\include
#     creating build\lib.win-amd64-3.9\clidriver\lib
#     copying clidriver\lib\db2app64.lib -> build\lib.win-amd64-3.9\clidriver\lib
#     copying clidriver\lib\db2cli64.lib -> build\lib.win-amd64-3.9\clidriver\lib
#     creating build\lib.win-amd64-3.9\clidriver\license
#     copying clidriver\license\odbc_REDIST.txt -> build\lib.win-amd64-3.9\clidriver\license
#     copying clidriver\license\odbc_notices.rtf -> build\lib.win-amd64-3.9\clidriver\license
#     creating build\lib.win-amd64-3.9\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_br.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_cn.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_cz.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_de.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_el.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_en.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_es.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_fr.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_in.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_it.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_jp.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_kr.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_lt.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_pl.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_ru.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_sl.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_tr.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_tw.rtf -> build\lib.win-amd64-3.9\clidriver\license\Windows
#     creating build\lib.win-amd64-3.9\clidriver\msg
#     creating build\lib.win-amd64-3.9\clidriver\msg\en_US
#     copying clidriver\msg\en_US\db2adm.mo -> build\lib.win-amd64-3.9\clidriver\msg\en_US
#     copying clidriver\msg\en_US\db2admh.mo -> build\lib.win-amd64-3.9\clidriver\msg\en_US
#     copying clidriver\msg\en_US\db2caem.mo -> build\lib.win-amd64-3.9\clidriver\msg\en_US
#     copying clidriver\msg\en_US\db2cklog.mo -> build\lib.win-amd64-3.9\clidriver\msg\en_US
#     copying clidriver\msg\en_US\db2cli.mo -> build\lib.win-amd64-3.9\clidriver\msg\en_US
#     copying clidriver\msg\en_US\db2clia1.lst -> build\lib.win-amd64-3.9\clidriver\msg\en_US
#     copying clidriver\msg\en_US\db2clias.lst -> build\lib.win-amd64-3.9\clidriver\msg\en_US
#     copying clidriver\msg\en_US\db2clih.mo -> build\lib.win-amd64-3.9\clidriver\msg\en_US
#     copying clidriver\msg\en_US\db2clit.mo -> build\lib.win-amd64-3.9\clidriver\msg\en_US
#     copying clidriver\msg\en_US\db2clp.mo -> build\lib.win-amd64-3.9\clidriver\msg\en_US
#     copying clidriver\msg\en_US\db2clp2.mo -> build\lib.win-amd64-3.9\clidriver\msg\en_US
#     copying clidriver\msg\en_US\db2fodc.mo -> build\lib.win-amd64-3.9\clidriver\msg\en_US
#     copying clidriver\msg\en_US\db2sql.mo -> build\lib.win-amd64-3.9\clidriver\msg\en_US
#     copying clidriver\msg\en_US\db2sqlh.mo -> build\lib.win-amd64-3.9\clidriver\msg\en_US
#     copying clidriver\msg\en_US\db2stt.mo -> build\lib.win-amd64-3.9\clidriver\msg\en_US
#     copying clidriver\msg\en_US\db2supp.mo -> build\lib.win-amd64-3.9\clidriver\msg\en_US
#     C:\ProgramData\Anaconda3\envs\IBM\lib\site-packages\setuptools\lib2to3_ex.py:36: SetuptoolsDeprecationWarning: 2to3 support is deprecated. If the project still requires Python 2 support, please migrate to a single-codebase solution or employ an independent conversion process.
#       warnings.warn(
#     Fixing build\lib.win-amd64-3.9\ibm_db_dbi.py build\lib.win-amd64-3.9\testfunctions.py build\lib.win-amd64-3.9\tests.py build\lib.win-amd64-3.9\certs\__init__.py build\lib.win-amd64-3.9\clidriver\__init__.py build\lib.win-amd64-3.9\ibm_db_tests\test_000_PrepareDb.py build\lib.win-amd64-3.9\ibm_db_tests\test_001_ConnDb.py build\lib.win-amd64-3.9\ibm_db_tests\test_002_ConnDbUncatalogedConn.py build\lib.win-amd64-3.9\ibm_db_tests\test_003_NumAffectedRows.py build\lib.win-amd64-3.9\ibm_db_tests\test_004_ConnWrongUserPwd.py build\lib.win-amd64-3.9\ibm_db_tests\test_005_ConnBadUserBadPwd.py build\lib.win-amd64-3.9\ibm_db_tests\test_006_ConnPassingOpts.py build\lib.win-amd64-3.9\ibm_db_tests\test_007_pConnPassingOpts.py build\lib.win-amd64-3.9\ibm_db_tests\test_008_ColumnInfo.py build\lib.win-amd64-3.9\ibm_db_tests\test_010_UpdateRowCount.py build\lib.win-amd64-3.9\ibm_db_tests\test_011_DeleteRowCount.py build\lib.win-amd64-3.9\ibm_db_tests\test_012_KeysetDrivenCursorSelect01.py build\lib.win-amd64-3.9\ibm_db_tests\test_013_KeysetDrivenCursorSelect02.py build\lib.win-amd64-3.9\ibm_db_tests\test_014_KeysetDrivenCursorNegativeRow.py build\lib.win-amd64-3.9\ibm_db_tests\test_015_InsertDeleteRowCount_01.py build\lib.win-amd64-3.9\ibm_db_tests\test_016_InsertDeleteRowCount_02.py build\lib.win-amd64-3.9\ibm_db_tests\test_017_selectRowcountPrefetchSTMTOpt.py build\lib.win-amd64-3.9\ibm_db_tests\test_018_selectRowcountPrefetchSetOpt.py build\lib.win-amd64-3.9\ibm_db_tests\test_019_selectRowcountPrefetchPrepOpt.py build\lib.win-amd64-3.9\ibm_db_tests\test_020_RollbackDelete.py build\lib.win-amd64-3.9\ibm_db_tests\test_021_CommitDelete.py build\lib.win-amd64-3.9\ibm_db_tests\test_022_RollbackInsert.py build\lib.win-amd64-3.9\ibm_db_tests\test_023_ColumnPrivileges.py build\lib.win-amd64-3.9\ibm_db_tests\test_024_ForeignKeys.py build\lib.win-amd64-3.9\ibm_db_tests\test_025_PrimaryKeys.py build\lib.win-amd64-3.9\ibm_db_tests\test_030_Result.py build\lib.win-amd64-3.9\ibm_db_tests\test_031_ResultIndexPosition.py build\lib.win-amd64-3.9\ibm_db_tests\test_032_ResultIndexName.py build\lib.win-amd64-3.9\ibm_db_tests\test_033_ResultOutSequenceColumn.py build\lib.win-amd64-3.9\ibm_db_tests\test_034_FetchAssoc.py build\lib.win-amd64-3.9\ibm_db_tests\test_035_FetchRow_01.py build\lib.win-amd64-3.9\ibm_db_tests\test_036_FetchRow_02.py build\lib.win-amd64-3.9\ibm_db_tests\test_037_FetchRowIndexPos.py build\lib.win-amd64-3.9\ibm_db_tests\test_038_FetchRowIndexPosNested_01.py build\lib.win-amd64-3.9\ibm_db_tests\test_039_FetchRowIndexPosNested_02.py build\lib.win-amd64-3.9\ibm_db_tests\test_03a_ResultNonExistCol.py build\lib.win-amd64-3.9\ibm_db_tests\test_040_FetchTuple.py build\lib.win-amd64-3.9\ibm_db_tests\test_041_FetchTupleMany_01.py build\lib.win-amd64-3.9\ibm_db_tests\test_042_FetchTupleMany_02.py build\lib.win-amd64-3.9\ibm_db_tests\test_043_FetchTupleMany_03.py build\lib.win-amd64-3.9\ibm_db_tests\test_044_FetchTupleMany_04.py build\lib.win-amd64-3.9\ibm_db_tests\test_045_FetchTupleBinaryData_01.py build\lib.win-amd64-3.9\ibm_db_tests\test_046_FetchTupleMany_05.py build\lib.win-amd64-3.9\ibm_db_tests\test_047_FetchTupleMany_06.py build\lib.win-amd64-3.9\ibm_db_tests\test_048_FetchTupleBinaryData_02.py build\lib.win-amd64-3.9\ibm_db_tests\test_049_InsertNoneParam.py build\lib.win-amd64-3.9\ibm_db_tests\test_050_AutocommitStatus.py build\lib.win-amd64-3.9\ibm_db_tests\test_051_SetAutocommit_01.py build\lib.win-amd64-3.9\ibm_db_tests\test_052_SetAutocommit_02.py build\lib.win-amd64-3.9\ibm_db_tests\test_053_AttrThruConn.py build\lib.win-amd64-3.9\ibm_db_tests\test_054_CursorType.py build\lib.win-amd64-3.9\ibm_db_tests\test_060_Tables_01.py build\lib.win-amd64-3.9\ibm_db_tests\test_061_Tables_02.py build\lib.win-amd64-3.9\ibm_db_tests\test_062_Tables_03.py build\lib.win-amd64-3.9\ibm_db_tests\test_063_Tables_04.py build\lib.win-amd64-3.9\ibm_db_tests\test_064_Tables_05.py build\lib.win-amd64-3.9\ibm_db_tests\test_065_FilterTableName.py build\lib.win- ...
#     Skipping optional fixer: buffer
#     Skipping optional fixer: idioms
#     Skipping optional fixer: set_literal
#     Skipping optional fixer: ws_comma
#     Fixing build\lib.win-amd64-3.9\ibm_db_dbi.py build\lib.win-amd64-3.9\testfunctions.py build\lib.win-amd64-3.9\tests.py build\lib.win-amd64-3.9\certs\__init__.py build\lib.win-amd64-3.9\clidriver\__init__.py build\lib.win-amd64-3.9\ibm_db_tests\test_000_PrepareDb.py build\lib.win-amd64-3.9\ibm_db_tests\test_001_ConnDb.py build\lib.win-amd64-3.9\ibm_db_tests\test_002_ConnDbUncatalogedConn.py build\lib.win-amd64-3.9\ibm_db_tests\test_003_NumAffectedRows.py build\lib.win-amd64-3.9\ibm_db_tests\test_004_ConnWrongUserPwd.py build\lib.win-amd64-3.9\ibm_db_tests\test_005_ConnBadUserBadPwd.py build\lib.win-amd64-3.9\ibm_db_tests\test_006_ConnPassingOpts.py build\lib.win-amd64-3.9\ibm_db_tests\test_007_pConnPassingOpts.py build\lib.win-amd64-3.9\ibm_db_tests\test_008_ColumnInfo.py build\lib.win-amd64-3.9\ibm_db_tests\test_010_UpdateRowCount.py build\lib.win-amd64-3.9\ibm_db_tests\test_011_DeleteRowCount.py build\lib.win-amd64-3.9\ibm_db_tests\test_012_KeysetDrivenCursorSelect01.py build\lib.win-amd64-3.9\ibm_db_tests\test_013_KeysetDrivenCursorSelect02.py build\lib.win-amd64-3.9\ibm_db_tests\test_014_KeysetDrivenCursorNegativeRow.py build\lib.win-amd64-3.9\ibm_db_tests\test_015_InsertDeleteRowCount_01.py build\lib.win-amd64-3.9\ibm_db_tests\test_016_InsertDeleteRowCount_02.py build\lib.win-amd64-3.9\ibm_db_tests\test_017_selectRowcountPrefetchSTMTOpt.py build\lib.win-amd64-3.9\ibm_db_tests\test_018_selectRowcountPrefetchSetOpt.py build\lib.win-amd64-3.9\ibm_db_tests\test_019_selectRowcountPrefetchPrepOpt.py build\lib.win-amd64-3.9\ibm_db_tests\test_020_RollbackDelete.py build\lib.win-amd64-3.9\ibm_db_tests\test_021_CommitDelete.py build\lib.win-amd64-3.9\ibm_db_tests\test_022_RollbackInsert.py build\lib.win-amd64-3.9\ibm_db_tests\test_023_ColumnPrivileges.py build\lib.win-amd64-3.9\ibm_db_tests\test_024_ForeignKeys.py build\lib.win-amd64-3.9\ibm_db_tests\test_025_PrimaryKeys.py build\lib.win-amd64-3.9\ibm_db_tests\test_030_Result.py build\lib.win-amd64-3.9\ibm_db_tests\test_031_ResultIndexPosition.py build\lib.win-amd64-3.9\ibm_db_tests\test_032_ResultIndexName.py build\lib.win-amd64-3.9\ibm_db_tests\test_033_ResultOutSequenceColumn.py build\lib.win-amd64-3.9\ibm_db_tests\test_034_FetchAssoc.py build\lib.win-amd64-3.9\ibm_db_tests\test_035_FetchRow_01.py build\lib.win-amd64-3.9\ibm_db_tests\test_036_FetchRow_02.py build\lib.win-amd64-3.9\ibm_db_tests\test_037_FetchRowIndexPos.py build\lib.win-amd64-3.9\ibm_db_tests\test_038_FetchRowIndexPosNested_01.py build\lib.win-amd64-3.9\ibm_db_tests\test_039_FetchRowIndexPosNested_02.py build\lib.win-amd64-3.9\ibm_db_tests\test_03a_ResultNonExistCol.py build\lib.win-amd64-3.9\ibm_db_tests\test_040_FetchTuple.py build\lib.win-amd64-3.9\ibm_db_tests\test_041_FetchTupleMany_01.py build\lib.win-amd64-3.9\ibm_db_tests\test_042_FetchTupleMany_02.py build\lib.win-amd64-3.9\ibm_db_tests\test_043_FetchTupleMany_03.py build\lib.win-amd64-3.9\ibm_db_tests\test_044_FetchTupleMany_04.py build\lib.win-amd64-3.9\ibm_db_tests\test_045_FetchTupleBinaryData_01.py build\lib.win-amd64-3.9\ibm_db_tests\test_046_FetchTupleMany_05.py build\lib.win-amd64-3.9\ibm_db_tests\test_047_FetchTupleMany_06.py build\lib.win-amd64-3.9\ibm_db_tests\test_048_FetchTupleBinaryData_02.py build\lib.win-amd64-3.9\ibm_db_tests\test_049_InsertNoneParam.py build\lib.win-amd64-3.9\ibm_db_tests\test_050_AutocommitStatus.py build\lib.win-amd64-3.9\ibm_db_tests\test_051_SetAutocommit_01.py build\lib.win-amd64-3.9\ibm_db_tests\test_052_SetAutocommit_02.py build\lib.win-amd64-3.9\ibm_db_tests\test_053_AttrThruConn.py build\lib.win-amd64-3.9\ibm_db_tests\test_054_CursorType.py build\lib.win-amd64-3.9\ibm_db_tests\test_060_Tables_01.py build\lib.win-amd64-3.9\ibm_db_tests\test_061_Tables_02.py build\lib.win-amd64-3.9\ibm_db_tests\test_062_Tables_03.py build\lib.win-amd64-3.9\ibm_db_tests\test_063_Tables_04.py build\lib.win-amd64-3.9\ibm_db_tests\test_064_Tables_05.py build\lib.win-amd64-3.9\ibm_db_tests\test_065_FilterTableName.py build\lib.win- ...
#     Skipping optional fixer: buffer
#     Skipping optional fixer: idioms
#     Skipping optional fixer: set_literal
#     Skipping optional fixer: ws_comma
#     running build_ext
#     building 'ibm_db' extension
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\ProgramData\Anaconda3\envs\IBM\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Akim van Eersel\\AppData\\Local\\Temp\\pip-install-0yykipwf\\ibm-db\\setup.py'"'"'; __file__='"'"'C:\\Users\\Akim van Eersel\\AppData\\Local\\Temp\\pip-install-0yykipwf\\ibm-db\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Akim van Eersel\AppData\Local\Temp\pip-record-5237twbo\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\ProgramData\Anaconda3\envs\IBM\Include\ibm-db' Check the logs for full command output.

# %% [markdown]
# When the command above completes, the `ibm_db` library is loaded in your notebook.
#
# ## Identify the database connection credentials
#
# Connecting to dashDB or DB2 database requires the following information:
#
# -   Driver Name
# -   Database name
# -   Host DNS name or IP address
# -   Host port
# -   Connection protocol
# -   User ID (or username)
# -   User Password
#
# **Notice:** To obtain credentials please refer to the instructions given in the first Lab of this course
#
# Now enter your database credentials below and execute the cell with `Shift` + `Enter`

# %%
#Replace the placeholder values with your actual Db2 hostname, username, and password:
dsn_hostname = "dashdb-txn-sbox-yp-lon02-04.services.eu-gb.bluemix.net" # e.g.: "dashdb-txn-sbox-yp-dal09-04.services.dal.bluemix.net"
dsn_uid = "xpx73158"        # e.g. "abc12345"
dsn_pwd = "YoueDb2Password"      # e.g. "7dBZ3wWt9XN6$o0J"

dsn_driver = "{IBM DB2 ODBC DRIVER}"
dsn_database = "BLUDB"            # e.g. "BLUDB"
dsn_port = "50000"                # e.g. "50000" 
dsn_protocol = "TCPIP"            # i.e. "TCPIP"

# %% [markdown]
# ## Create the DB2 database connection
#
# Ibm_db API uses the IBM Data Server Driver for ODBC and CLI APIs to connect to IBM DB2 and Informix.
#
# Lets build the dsn connection string using the credentials you entered above

# %%
#DO NOT MODIFY THIS CELL. Just RUN it with Shift + Enter
#Create the dsn connection string
dsn = (
    "DRIVER={0};"
    "DATABASE={1};"
    "HOSTNAME={2};"
    "PORT={3};"
    "PROTOCOL={4};"
    "UID={5};"
    "PWD={6};").format(dsn_driver, dsn_database, dsn_hostname, dsn_port, dsn_protocol, dsn_uid, dsn_pwd)

#print the connection string to check correct values are specified
print(dsn)

# %% [markdown]
# Now establish the connection to the database

# %%
#DO NOT MODIFY THIS CELL. Just RUN it with Shift + Enter
#Create database connection

try:
    conn = ibm_db.connect(dsn, "", "")
    print ("Connected to database: ", dsn_database, "as user: ", dsn_uid, "on host: ", dsn_hostname)

except:
    print ("Unable to connect: ", ibm_db.conn_errormsg() )

# %% [markdown]
# Congratulations if you were able to connect successfuly. Otherwise check the error and try again.

# %%
#Retrieve Metadata for the Database Server
server = ibm_db.server_info(conn)

print ("DBMS_NAME: ", server.DBMS_NAME)
print ("DBMS_VER:  ", server.DBMS_VER)
print ("DB_NAME:   ", server.DB_NAME)

# %%
#Retrieve Metadata for the Database Client / Driver
client = ibm_db.client_info(conn)

print ("DRIVER_NAME:          ", client.DRIVER_NAME) 
print ("DRIVER_VER:           ", client.DRIVER_VER)
print ("DATA_SOURCE_NAME:     ", client.DATA_SOURCE_NAME)
print ("DRIVER_ODBC_VER:      ", client.DRIVER_ODBC_VER)
print ("ODBC_VER:             ", client.ODBC_VER)
print ("ODBC_SQL_CONFORMANCE: ", client.ODBC_SQL_CONFORMANCE)
print ("APPL_CODEPAGE:        ", client.APPL_CODEPAGE)
print ("CONN_CODEPAGE:        ", client.CONN_CODEPAGE)

# %% [markdown]
# ## Close the Connection
#
# We free all resources by closing the connection. Remember that it is always important to close connections so that we can avoid unused connections taking up resources.

# %%
ibm_db.close(conn)

# %% [markdown]
# ## Summary
#
# In this tutorial you established a connection to a DB2 database on Cloud database from a Python notebook using ibm_db API.

# %% [markdown]
# ## Author
#
# <a href="https://www.linkedin.com/in/ravahuja">Rav Ahuja</a>
#
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description                 |
# | ----------------- | ------- | ---------- | ---------------------------------- |
# | 2020-08-28        | 2.0     | Lavanya    | Moved lab to course repo in GitLab |
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
